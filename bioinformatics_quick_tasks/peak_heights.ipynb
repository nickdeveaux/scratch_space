# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import peakutils

# %%
df = pd.read_csv('/Users/ndeveaux/Downloads/20170222_WT_CNS_S59_noMito_fragmentLengths_all.txt')

# %%
plt.figure(figsize=(20,20))
p = sns.distplot(df['Length']);

# %%
x,y = p.get_lines()[0].get_data()

# %%
indexes = peakutils.indexes(df['Length'])
interpolatedIndexes = peakutils.interpolate(range(0, len(df['Length'])), df['Length'], ind=indexes)

# %%
indexes
# Out:
# array([], dtype=int64)

# %%
y
# Out:
# array([  3.20321676e-05,   3.42682460e-05,   2.44844707e-03,
#          3.85069112e-03,   2.67638378e-03,   2.04840629e-03,
#          1.57546623e-03,   1.84852920e-03,   2.36569247e-03,
#          4.12300865e-03,   3.92569940e-03,   3.71914154e-03,
#          3.34321107e-03,   2.62289636e-03,   1.75299023e-03,
#          1.17339219e-03,   8.30438549e-04,   6.97289153e-04,
#          6.61514831e-04,   7.36921692e-04,   8.74241957e-04,
#          1.09632971e-03,   1.25412586e-03,   1.33717726e-03,
#          1.27749867e-03,   1.10684628e-03,   8.47209340e-04,
#          6.18492242e-04,   4.58138303e-04,   3.81791442e-04,
#          3.59968844e-04,   3.85121724e-04,   4.31879693e-04,
#          5.02366312e-04,   5.58711260e-04,   5.97471370e-04,
#          5.86068764e-04,   5.38414419e-04,   4.49136742e-04,
#          3.57111646e-04,   2.80244522e-04,   2.33267778e-04,
#          2.12065094e-04,   2.14772468e-04,   2.30962664e-04,
# ...

# %%
import scipy.signal

# %%
scipy.signal.argrelmax(y)
# Out:
# (array([  3,   9,  23,  35,  47,  59,  83,  87,  89,  91,  93,  95,  97,
#          99, 101, 103, 105, 107, 109, 111, 113, 115, 118, 120, 122, 124, 126]),)

# %%
peaks = x[scipy.signal.argrelmax(y)]

# %%
for i in range(len(peaks) - 1):
    print peaks[i + 1] - peaks[i]
# Out:
# 94.1644425285
# 219.717032566
# 188.328885057
# 188.328885057
# 188.328885057
# 376.657770114
# 62.776295019
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 47.0822212642
# 31.3881475095
# 31.3881475095
# 31.3881475095
# 31.3881475095

# %%
586.21889799 - 397.89001293
# Out:
# 188.32888505999995

# %%
peaks
# Out:
# array([   84.00853784,   178.17298037,   397.89001293,   586.21889799,
#          774.54778305,   962.8766681 ,  1339.53443822,  1402.31073324,
#         1433.69888075,  1465.08702826,  1496.47517576,  1527.86332327,
#         1559.25147078,  1590.63961829,  1622.0277658 ,  1653.41591331,
#         1684.80406082,  1716.19220833,  1747.58035584,  1778.96850335,
#         1810.35665086,  1841.74479837,  1888.82701963,  1920.21516714,
#         1951.60331465,  1982.99146216,  2014.37960967])

# %%
peaks[1]
# Out:
# 178.17298036637908
